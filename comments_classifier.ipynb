# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import json

# %%
from bangla_comments_separator import bangla_comments

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(bangla_comments)

k = 3
model = KMeans(n_clusters=k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)

order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()


def check_similarity(text):
    count1 = count2 = count3 = 0
    for word in text:
        if word in terms[0]:
            count1 += 1
        elif word in terms[1]:
            count2 += 1
        elif word in terms[2]:
            count3 += 1
    if max(count1, count2, count3) == count1:
        return "class1"
    elif max(count1, count2, count3) == count2:
        return "class2"
    else:
        return "class3"


classified = {
    "class1": [],
    "class2": [],
    "class3": []
}

for line in bangla_comments:
    class_name = check_similarity(line)
    classified[class_name].append(line)

print(classified)
# Out:
# {'class1': ['আপনাদের কাছে একটাই অনুরোধ ক্যাশ আউট চার্জ টা একটু কমান তাছাড়া বিকাশ আমার খুব ভালো লাগে শুধু ক্যাশ আউট চার্জ টাই ভেজাল', 'এরটেল এ্যাপ থেকে এমবি কিনছিলাম\t\tআর ওফার ছিলো ২-৪ টা এর ভিতরে কিনলে ২৫% ডিসকাউন্ট\t\tআর এ্যপ থেকে সরাসরি বিকাশে রিচার্জ করা হয়েছে।। কিন্তু আমি ত ডিসকাউন্ট পেলাম না সেই ক্ষেত্রে আমি কি করতে পারি', 'স্যার আমার সিম বন্ধ হয়ে গেছে এটা আবার নতুন করে উঠায়ছি কিন্তু পুরাতন বিকাশ চালু হচ্ছে না কিন্তুু কেন?', 'আপনারা নন বিকাশ একাউন্টে টাকা সেন্ড মানি করলে ১৫ টাকা দিচ্ছিলেন সে অফার কি বন্ধ', 'একটা ইস্যু ক্রিয়েট করছিলাম গত মাসের ২৮ তারিখ কিন্তু এখনো কোন আপডেট পাইনি 😥 ইস্যু নং- 8180245', '11 টাকা রিচার্জে 16 টাকা ক্যাশব্যাক এই অফারটা আমি একবার নিয়েছি আবারো যদি নি তাহলে কি দেবে', '১১ টাকা রিচার্জ করে আমি কোন ক্যাশব্যাক অফার পাইনি', 'ক্যশআউট চার্জটা কমান প্লিজ', 'হ্যালো আসসালামুয়ালাইকুম সিম দিয়া বিকাশ তো একটাই খোলা জানালা দিয়া যদি আমি ওই সিমে বিকাশ আইডি কার্ড আইডি বাদ দিয়ে অন্য সিমে বিকাশ করা যাবে', 'বিকাশ সিমের মালিকানা  পরিবর্তন করা যাবে??? কি ভাবে করতে পারি???', ' বিকাশ  দিয়ে  পল্লী বিদ্যুৎ বিল দিলে কোন খরচ হবে কি না কোন চার্জ নাই একটু  বলবেন', 'আমি তো পেয়েছি', 'Disbursement মানে কী..? আমার কাছে DM1902 থেকে কিছু টাকা আসছে..... বিষয়টা বুঝিয়ে বলবেন', 'রেফার করে অ্যাপ ডাউনলোড করছি কালকে\t\tকিন্তু বিকাশ খুলছি আজকে\t\tএখন আমি রেফার এর কমিশন পব।', 'আচ্ছা ১১ টাকা রির্চাজে ১৬ টাকা ক্যাশব্যাকের অফারটা চলাকালীন সময়ে কতবার ক্যাশব্যাক পাবো???', '১১ টাকা রিচার্জে ১৬ টাকা  কেশবেক অফারটা কি আছে', 'আপনারা নন বিকাশ একাউন্টে টাকা সেন্ড মানি করলে ১৫ টাকা দিচ্ছিলেন সে অফার কি বন্ধ', '১১ টাকা রিচার্জে ১৬ টাকা  কেশবেক অফারটা কি আছে', '11 টাকা রিচার্জে 16 টাকা ক্যাশব্যাক এই অফারটা আমি একবার নিয়েছি আবারো যদি নি তাহলে কি দেবে', 'হ্যালো আসসালামুয়ালাইকুম সিম দিয়া বিকাশ তো একটাই খোলা জানালা দিয়া যদি আমি ওই সিমে বিকাশ আইডি কার্ড আইডি বাদ দিয়ে অন্য সিমে বিকাশ করা যাবে', 'আচ্ছা ১১ টাকা রির্চাজে ১৬ টাকা ক্যাশব্যাকের অফারটা চলাকালীন সময়ে কতবার ক্যাশব্যাক পাবো???', 'স্যার আমার সিম বন্ধ হয়ে গেছে এটা আবার নতুন করে উঠায়ছি কিন্তু পুরাতন বিকাশ চালু হচ্ছে না কিন্তুু কেন?', 'রেফার করে অ্যাপ ডাউনলোড করছি কালকে\t\tকিন্তু বিকাশ খুলছি আজকে\t\tএখন আমি রেফার এর কমিশন পব।', 'আচ্ছা ১১ টাকা রির্চাজে ১৬ টাকা ক্যাশব্যাকের অফারটা কি এখনো চালু আছে?', 'আপনাদের কাছে একটাই অনুরোধ ক্যাশ আউট চার্জ টা একটু কমান তাছাড়া বিকাশ আমার খুব ভালো লাগে শুধু ক্যাশ আউট চার্জ টাই ভেজাল', 'বিকাশ সিমের মালিকানা  পরিবর্তন করা যাবে??? কি ভাবে করতে পারি???', 'ক্যশআউট চার্জটা কমান প্লিজ', 'আমি আমার আইডি কার্ড দিয়ে বিকাশ একায়োন্ট খুলতে পারছি না কেন\tজানতে পারি\t;2020-12-07T08:53:16+0000', ' ভুল নাম্বারে টাকা চলে গেলে কি করনীয় ', 'আপনাদের রিচার্জ ক্যাশব্যাক অফার গুলো বলুন প্লিজ', 'আমি এপ এ রেজিস্ট্রার না করে কুইজ বিজয়ী হতে পারব', 'বিকাশে টাকা রাখলে কোনো মুনাফা আসবে', 'ফরিদপুরের পল্লী বিদ্যুত বিল বিকাশের মাধ্যমে নেওয়া হয় কি ???', 'এটা খুব ভালো', 'সর্বোচ্চ কতবার পাওয়া যাবে।', 'আমি ৫ দিন হল পাইনি\tএর কারন কি?', 'বিদ্যুৎ বিল করতে পারি না কেন', 'ডাস্ বাংলা কাড থেকে কি বিকাশে আড মানি করা যায়?', 'বিদদূত বিলে চার্চ ফি  না নেওয়ার দাবি জানাচ্ছি।', '11 টাকা রিচার্জ কি শুধু একবার', 'আমি এজেন্ট হতে চাই', 'ভালো ', '২ টি রেফার করে মাএ ২০ টাকা পাইছি  বাকি টা ইতিহাস', 'আমি ডাচ বাংলা ব্যাংক থেকে এড মানি করব কিভাবে ', '10 টাকা রিচার্জ  এ 10 টাকা chasback ata ki sobar jonno', 'ভালো', 'আমার একটা বিকাশ  একাউন্ট আছে কিন্তু সেই সিম টা নষ্ট হলে গেছে টাকা  তুলবো কী ভাবে?', 'সিম রিপলেস করেছি একাউন্ট কতখন পরে চালু হবে', 'একটা একাউন্ট থেকে প্রতিদিন কয়টি রিচার্জ করা যাবে', 'আচ্ছা রেফার কি..??কিভাবে করে..? যদি একটু বুঝিয়ে বলতেন', 'আমি আজ রেফার করছি আমি কত টাকা পাবো আর আমি কবো বোনাস পাবে', 'একজনকে রেপার করে এ্যাপে লগইন করালাম বাট\t২০ টাকা দুইদিন পার হলো তবু ও পেলাম না।', 'আমার বিকাশ একাউন্টে টাকা ডুকানো যাচ্ছে না\tবা কেউ টাকা পাঠালে একাউন্টে আসছে না।', '২৫ টাকা রিচাজ করলে ৫০ টাকা পাব???অফার টি আছে???', 'আমার বন্ধ সিমে বিকাশ একাউন্টটি চালু সিমে ট্রান্সফার করতে চাই\tকি করতে হবে।', 'আমি কুইজ খেলে ৬ সেকেন্ড উওর দিছি।। এবং সাথে সাথে সেন্ড মানি করেছি কিন্তু বোনাস পাই নেই।।।কেনো আমাকে বলবেন', 'রেফার দিয়ে নতুন একাউন্ট খুললাম। নতুন একাউন্টেও কোন টাকা পেলাম না। আর রেফারেও কোন টাকা পেলাম না এখনো। টাকা ট্রান্সফার ও ...

# %%
# dumping into a csv file
with open("classified_comments.json", 'w') as file:
    json.dump(classified, file)
